# %%
#import packages
#!pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.29.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 10.8 MB/s eta 0:00:0000:0100:01
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from selenium) (4.12.2)
# Collecting websocket-client~=1.8
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
# Collecting trio~=0.17
#   Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 9.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: attrs>=23.2.0 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (25.1.0)
# Collecting sniffio>=1.3.0
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: websocket-client, sniffio, outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
# Successfully installed exceptiongroup-1.2.2 h11-0.14.0 outcome-1.3.0.post0 selenium-4.29.0 sniffio-1.3.1 trio-0.29.0 trio-websocket-0.12.2 websocket-client-1.8.0 wsproto-1.2.0

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: requests in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from requests->webdriver-manager) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rupalimohapatra/anaconda3/lib/python3.10/site-packages (from requests->webdriver-manager) (1.26.14)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.0.1 webdriver-manager-4.0.2

# %%
import time
import pandas as pd
import os

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException, TimeoutException, ElementClickInterceptedException, StaleElementReferenceException

# %%
# URL for Data Analyst jobs in Sweden
url = 'https://www.linkedin.com/jobs/search/?currentJobId=4034151343&geoId=105117694&keywords=Data%20Analyst&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true&trk=public_jobs_jobs-search-bar_search-submit'

# %%
# Setup WebDriver with automatic ChromeDriver management
service = Service(ChromeDriverManager().install())
options = webdriver.ChromeOptions()

# %%
# Uncomment the next line if you want to run the browser in headless mode
# options.add_argument('--headless')
options.add_argument('--disable-blink-features=AutomationControlled')  # Try to avoid detection
options.add_argument('--start-maximized')  # Start with maximized window
options.add_experimental_option('excludeSwitches', ['enable-automation'])  # Hide automation
options.add_experimental_option('useAutomationExtension', False)  # Disable automation extension

# %%
driver = webdriver.Chrome(service=service, options=options)
# Open LinkedIn jobs page
driver.get(url)
print("Waiting for page to load...")
time.sleep(5)  # Give time for the page to load
# Out:
# Waiting for page to load...

# %%
# Lists to store job data
job_titles = []
company_names = []
cities = []
posted_dates = []
applicant_counts = []
seniority_levels = []
employment_types = []
job_functions = []
industries_list = []

# %%
#Safely find an element with proper wait and error handling
def safe_find_element(parent, by, value, wait_time=3):
    try:
        element = WebDriverWait(parent, wait_time).until(
            EC.presence_of_element_located((by, value))
        )
        return element
    except (TimeoutException, NoSuchElementException):
        return None

# %%
#Safely get text from an element
def safe_get_text(element):
    if element:
        try:
            return element.text.strip()
        except:
            pass
    return "N/A"

# %%
#Collect basic job data from the listing card
def collect_basic_job_data(job_listing):
    try:
        title_element = safe_find_element(job_listing, By.CSS_SELECTOR, 'h3.base-search-card__title')
        company_element = safe_find_element(job_listing, By.CSS_SELECTOR, 'h4.base-search-card__subtitle')
        location_element = safe_find_element(job_listing, By.CSS_SELECTOR, 'span.job-search-card__location')
        
        title = safe_get_text(title_element)
        company = safe_get_text(company_element)
        location = safe_get_text(location_element)
        
        return {
            "title": title,
            "company": company, 
            "location": location
        }
    except Exception as e:
        print(f"Error collecting basic job data: {e}")
        return {"title": "N/A", "company": "N/A", "location": "N/A"}

# %%
#Extract detailed information for the currently selected job
def extract_job_details():
    time.sleep(2)  # Wait for job details to load
    
    # Get job details pane
    details_pane = safe_find_element(driver, By.CSS_SELECTOR, 'div.details-pane_content.details-pane_content--show')
    
    if not details_pane:
        print("Job details pane not found")
        return {
            "posted_date": "N/A",
            "applicant_count": "N/A",
            "seniority_level": "N/A",
            "employment_type": "N/A",
            "job_function": "N/A",
            "industries": "N/A"
        }
    
    # Extract posted date
    try:
        posted_date_element = safe_find_element(
            details_pane, 
            By.CSS_SELECTOR, 
            'span.posted-time-ago_text.topcard_flavor--metadata'
        )
        posted_date = safe_get_text(posted_date_element)
    except:
        posted_date = "N/A"
        
    # Extract applicant count
    try:
        applicant_element = safe_find_element(
            details_pane, 
            By.CSS_SELECTOR, 
            'figure.num-applicants_figure.topcardflavor--metadata.topcard_flavor--bullet figcaption'
        )
        applicant_count = safe_get_text(applicant_element)
    except:
        applicant_count = "N/A"
    
    # Find the job criteria section
    job_criteria_list = safe_find_element(
        details_pane, 
        By.CSS_SELECTOR, 
        'ul.description__job-criteria-list'
    )
    
    # Initialize job criteria variables
    seniority_level = "N/A"
    employment_type = "N/A"
    job_function = "N/A"
    industries = "N/A"
    
    # Extract job criteria if section exists
    if job_criteria_list:
        criteria_items = job_criteria_list.find_elements(By.CSS_SELECTOR, 'li.description__job-criteria-item')
        
        for item in criteria_items:
            # Get the criteria item label
            label_element = safe_find_element(item, By.CSS_SELECTOR, 'h3.description__job-criteria-subheader')
            criteria_text = safe_find_element(item, By.CSS_SELECTOR, 'span.description__job-criteria-text')
            
            label = safe_get_text(label_element)
            value = safe_get_text(criteria_text)
            
            if "seniority" in label.lower():
                seniority_level = value
            elif "employment" in label.lower():
                employment_type = value
            elif "function" in label.lower():
                job_function = value
            elif "industr" in label.lower():
                industries = value
    
    return {
        "posted_date": posted_date,
        "applicant_count": applicant_count,
        "seniority_level": seniority_level,
        "employment_type": employment_type,
        "job_function": job_function,
        "industries": industries
    }

# %%
#Scroll element into view
def scroll_to_element(element):
    try:
        driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", element)
        time.sleep(0.5)
    except:
        pass

# %%
#Process job listings and extract detailed information
def process_job_listings():
    try:
        # Find the job results list
        results_list = safe_find_element(
            driver, 
            By.CSS_SELECTOR, 
            'ul.jobs-search__results-list'
        )
        
        if not results_list:
            print("Results list not found")
            return False
        
        # Find all job listings
        job_listings = results_list.find_elements(By.TAG_NAME, 'li')
        print(f"Found {len(job_listings)} job listings")
        
        # Process each job listing in the current view
        for job_index, job in enumerate(job_listings):
            # Skip jobs we've already processed
            if job_index < len(job_titles):
                continue
                
            try:
                # First collect the basic data
                basic_data = collect_basic_job_data(job)
                
                # Find the job card link (this is the full card link that's clickable)
                job_card_link = safe_find_element(job, By.CSS_SELECTOR, 'a.base-card__full-link')
                
                if not job_card_link:
                    print(f"Job card link not found for job #{job_index + 1}")
                    continue
                
                # Scroll to make the link visible
                scroll_to_element(job_card_link)
                
                # Using JavaScript to click the link (more reliable than selenium click)
                try:
                    driver.execute_script("arguments[0].click();", job_card_link)
                    print(f"Clicked on job {job_index + 1} using JavaScript")
                except Exception as e:
                    print(f"JavaScript click failed: {e}")
                    continue
                
                # Extract detailed job information
                details = extract_job_details()
                
                # Add all data to our lists
                job_titles.append(basic_data["title"])
                company_names.append(basic_data["company"])
                cities.append(basic_data["location"])
                posted_dates.append(details["posted_date"])
                applicant_counts.append(details["applicant_count"])
                seniority_levels.append(details["seniority_level"])
                employment_types.append(details["employment_type"])
                job_functions.append(details["job_function"])
                industries_list.append(details["industries"])
                
                print(f"Processed job {job_index + 1}: {basic_data['title']} | {basic_data['company']} | {basic_data['location']}")
                
                # Wait a moment before processing the next job
                time.sleep(2)
                
            except StaleElementReferenceException:
                # If elements become stale, break and try again with fresh elements
                print("Stale element reference, refreshing job list")
                break
                
            except Exception as e:
                print(f"Error processing job listing #{job_index + 1}: {e}")
                continue
                
        return True
    
    except Exception as e:
        print(f"Error in process_job_listings: {e}")
        return False

# %%
#Click on the 'See more jobs' button if available
def click_see_more_jobs(): 
    try:
        # First scroll to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
        
        # Look for the 'See more jobs' button
        see_more_button = safe_find_element(
            driver, 
            By.CSS_SELECTOR, 
            'button.infinite-scroller_show-more-button.infinite-scroller_show-more-button--visible'
        )
        
        if see_more_button and see_more_button.is_displayed():
            scroll_to_element(see_more_button)
            
            # Try to click with JavaScript (more reliable)
            try:
                driver.execute_script("arguments[0].click();", see_more_button)
                print("Clicked 'See more jobs' button with JavaScript")
                time.sleep(3)  # Wait for more jobs to load
                return True
            except Exception as e:
                print(f"JavaScript click failed for 'See more jobs' button: {e}")
                return False
        else:
            print("'See more jobs' button not found or not visible")
            return False
            
    except Exception as e:
        print(f"Error in click_see_more_jobs: {e}")
        return False

# %%
# Main scraping loop
max_iterations = 5  # Maximum number of iterations
no_new_jobs_count = 0  # Counter for iterations with no new jobs
max_no_new_jobs = 2  # Maximum allowed iterations with no new jobs

for iteration in range(max_iterations):
    print(f"\nIteration {iteration + 1}/{max_iterations}")
    
    # Track current job count
    current_count = len(job_titles)
    
    # Process job listings
    process_job_listings()
    
    # Check if we got new jobs
    if len(job_titles) == current_count:
        no_new_jobs_count += 1
        print(f"No new jobs found in this iteration. Count: {no_new_jobs_count}/{max_no_new_jobs}")
    else:
        no_new_jobs_count = 0
        print(f"Found {len(job_titles) - current_count} new jobs")
    
    # If we had several iterations with no new jobs, we're probably at the end
    if no_new_jobs_count >= max_no_new_jobs:
        print("No new jobs found for several iterations, ending scraping")
        break
    
    # Try to click "See more jobs" button
    clicked = click_see_more_jobs()
    
    # If we couldn't click the button and we've processed all visible jobs, we're done
    if not clicked and len(job_titles) == current_count:
        print("No more jobs to load, ending scraping")
        break
        
    print(f"Total jobs collected so far: {len(job_titles)}")

# Create DataFrame with the collected data
print(f"\nCreating DataFrame with {len(job_titles)} jobs")
jobs_data = {
    'Title': job_titles,
    'Company': company_names,
    'City': cities,
    'Posted Date': posted_dates,
    'Applicant Count': applicant_counts,
    'Seniority Level': seniority_levels,
    'Employment Type': employment_types,
    'Job Function': job_functions,
    'Industries': industries_list
}

df = pd.DataFrame(jobs_data)

# Save to CSV
csv_filename = 'linkedin_data_analyst_jobs_scraped.csv'
df.to_csv(csv_filename, index=False)
print(f"Data saved to {csv_filename}")

# Display first few rows of data
print("\nPreview of collected data:")
print(df.head())

# Display data collection statistics
print(f"\nTotal jobs collected: {len(df)}")
print(f"Unique companies: {df['Company'].nunique()}")
print(f"Unique cities: {df['City'].nunique()}")
print(f"Unique seniority levels: {df['Seniority Level'].nunique()}")
print(f"Unique employment types: {df['Employment Type'].nunique()}")
# Out:
# Iteration 1/5
# Found 58 job listings
# Clicked on job 1 using JavaScript
# Job details pane not found
# Processed job 1: Data Analyst | LTIMindtree | Stockholm County, Sweden
# Clicked on job 2 using JavaScript
# Job details pane not found
# Processed job 2: Business & Data Analyst | Karo Healthcare | Stockholm, Stockholm County, Sweden
# Clicked on job 3 using JavaScript
# Job details pane not found
# Processed job 3: Data Analyst | Avy | Stockholm, Stockholm County, Sweden
# Clicked on job 4 using JavaScript
# Job details pane not found
# Processed job 4: Data Analyst | RED Global | Stockholm, Stockholm County, Sweden
# Clicked on job 5 using JavaScript
# Job details pane not found
# Processed job 5: Data Analyst | Capgemini | Stockholm, Stockholm County, Sweden
# Clicked on job 6 using JavaScript
# Job details pane not found
# Processed job 6: Senior Data Analyst | CloudArt Solutions | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 7 using JavaScript
# Job details pane not found
# Processed job 7: Data Analyst | Deploja | Solna, Stockholm County, Sweden
# Clicked on job 8 using JavaScript
# Job details pane not found
# Processed job 8: Data Analyst | Deploja | Malmo, Skåne County, Sweden
# Clicked on job 9 using JavaScript
# Job details pane not found
# Processed job 9: Stanowisko ds. zarządzania obszarem BI i HD-specjalność inżynierii systemów Hurtowni Danych | ZUS | Sweden
# Clicked on job 10 using JavaScript
# Job details pane not found
# Processed job 10: Data Analyst | Stegra | Stockholm, Stockholm County, Sweden
# Clicked on job 11 using JavaScript
# Job details pane not found
# Processed job 11: Senior Data Analyst | CloudArt Solutions | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 12 using JavaScript
# Job details pane not found
# Processed job 12: Data Analyst | SeenThis | Stockholm, Stockholm County, Sweden
# Clicked on job 13 using JavaScript
# Job details pane not found
# Processed job 13: Algoritmutveckling / Reglerteknik / Modellbaserad Utveckling Lund | Combine | Lund, Skåne County, Sweden
# Clicked on job 14 using JavaScript
# Job details pane not found
# Processed job 14: Analytical Consultant | NielsenIQ | Stockholm, Stockholm County, Sweden
# Clicked on job 15 using JavaScript
# Job details pane not found
# Processed job 15: Business Intelligence Analyst | Hitachi Energy | Ludvika, Dalarna County, Sweden
# Clicked on job 16 using JavaScript
# Job details pane not found
# Processed job 16: Stanowisko ds. zarządzania obszarem BI i HD-specjalność inżynierii systemów Business Intelligence | ZUS | Sweden
# Clicked on job 17 using JavaScript
# Job details pane not found
# Processed job 17: Data Modeler & Data Analyst Consultant | LTIMindtree | Stockholm, Stockholm County, Sweden
# Clicked on job 18 using JavaScript
# Job details pane not found
# Processed job 18: Data Analyst | Blockchain Staffing Ninja | Sweden
# Clicked on job 19 using JavaScript
# Job details pane not found
# Processed job 19: Data Analyst | AI Staffing Ninja | Sweden
# Clicked on job 20 using JavaScript
# Job details pane not found
# Processed job 20: Marketing Data Analyst | Sony Music Sweden | Stockholm, Stockholm County, Sweden
# Clicked on job 21 using JavaScript
# Job details pane not found
# Processed job 21: Data Analyst (0 Experience Required) | Peroptyx | Sweden
# Clicked on job 22 using JavaScript
# Job details pane not found
# Processed job 22: Data Analyst (Data Visualization) - Senior | Professional Galaxy AB | Stockholm, Stockholm County, Sweden
# Clicked on job 23 using JavaScript
# Job details pane not found
# Processed job 23: Junior Office Consultant | Cushman & Wakefield | Stockholm, Stockholm County, Sweden
# Clicked on job 24 using JavaScript
# Job details pane not found
# Processed job 24: Data Analyst | Signific | Södermalm, Stockholm County, Sweden
# Clicked on job 25 using JavaScript
# Job details pane not found
# Processed job 25: Business Analyst - Data, Analytics & AI Use Cases | inventYOU IT Consulting | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 26 using JavaScript
# Job details pane not found
# Processed job 26: Business Intelligence Analyst | GlobalConnect | Stockholm, Stockholm County, Sweden
# Clicked on job 27 using JavaScript
# Job details pane not found
# Processed job 27: Senior Data Analyst | Trustly | Stockholm, Stockholm County, Sweden
# Clicked on job 28 using JavaScript
# Job details pane not found
# Processed job 28: Data Analyst (0 Experience Required) | Peroptyx | Stockholm County, Sweden
# Clicked on job 29 using JavaScript
# Job details pane not found
# Processed job 29: Reporting & BI - Product & Market, AS Performance | Nissan Motor Corporation | Stockholm, Stockholm County, Sweden
# Clicked on job 30 using JavaScript
# Job details pane not found
# Processed job 30: Senior Data Analyst (m/f/d) | Riverty | Stockholm, Stockholm County, Sweden
# Clicked on job 31 using JavaScript
# Job details pane not found
# Processed job 31: Data Modeller | Whitehall Resources | Stockholm, Stockholm County, Sweden
# Clicked on job 32 using JavaScript
# Job details pane not found
# Processed job 32: Data Analyst | Atea Sverige | Stockholm, Stockholm County, Sweden
# Clicked on job 33 using JavaScript
# Job details pane not found
# Processed job 33: Product Compliance Data Analyst | Polestar | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 34 using JavaScript
# Job details pane not found
# Processed job 34: Data Analyst | Adage | Stockholm, Stockholm County, Sweden
# Clicked on job 35 using JavaScript
# Job details pane not found
# Processed job 35: Stanowisko ds. zarządzania obszarem BI i HD-specjalność analityki biznesowej | ZUS | Sweden
# Clicked on job 36 using JavaScript
# Job details pane not found
# Processed job 36: Data Engineer / Production Analyst [Game Intelligence] | Massive Entertainment - A Ubisoft Studio | Malmo, Skåne County, Sweden
# Clicked on job 37 using JavaScript
# Job details pane not found
# Processed job 37: Data Analyst | Signific | Stockholm, Stockholm County, Sweden
# Clicked on job 38 using JavaScript
# Job details pane not found
# Processed job 38: Senior BI Consultant | Stormyran | Stockholm, Stockholm County, Sweden
# Clicked on job 39 using JavaScript
# Job details pane not found
# Processed job 39: Senior Data Analyst | Epidemic Sound | Stockholm, Stockholm County, Sweden
# Clicked on job 40 using JavaScript
# Job details pane not found
# Processed job 40: Data Engineer | iPlace | Stockholm, Stockholm County, Sweden
# Clicked on job 41 using JavaScript
# Job details pane not found
# Processed job 41: Data Engineer | GeekSoft Consulting | Stockholm, Stockholm County, Sweden
# Clicked on job 42 using JavaScript
# Job details pane not found
# Processed job 42: Data Science Trainee and Intern | CONNECTMETA.AI | Sweden
# Clicked on job 43 using JavaScript
# Job details pane not found
# Processed job 43: Data Engineer | Aqilea | Stockholm, Stockholm County, Sweden
# Clicked on job 44 using JavaScript
# Job details pane not found
# Processed job 44: Data Analysis Manager | Humana AB | Stockholm, Stockholm County, Sweden
# Clicked on job 45 using JavaScript
# Job details pane not found
# Processed job 45: Senior Power BI Data Analyst | Professional Galaxy AB | Södertälje, Stockholm County, Sweden
# Clicked on job 46 using JavaScript
# Job details pane not found
# Processed job 46: Data Engineer | Explore Consulting SWE | Stockholm, Stockholm County, Sweden
# Clicked on job 47 using JavaScript
# Job details pane not found
# Processed job 47: Analyticskonsult till energisektorn | Sopra Steria | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 48 using JavaScript
# Job details pane not found
# Processed job 48: Impact Analyzer | Nissan Motor Corporation | Stockholm, Stockholm County, Sweden
# Clicked on job 49 using JavaScript
# Job details pane not found
# Processed job 49: Samordnare med fokus på datadriven utveckling | Värnamo kommun | Värnamo, Jönköping County, Sweden
# Clicked on job 50 using JavaScript
# Job details pane not found
# Processed job 50: Product Analyst | King | Stockholm, Stockholm County, Sweden
# Clicked on job 51 using JavaScript
# Job details pane not found
# Processed job 51: Quantitative Analyst | Kambi | Stockholm, Stockholm County, Sweden
# Clicked on job 52 using JavaScript
# Job details pane not found
# Processed job 52: Data Engineer | Svenska kraftnät | Stockholm, Stockholm County, Sweden
# Clicked on job 53 using JavaScript
# Job details pane not found
# Processed job 53: Data Engineer | Parallel Consulting | Stockholm, Stockholm County, Sweden
# Clicked on job 54 using JavaScript
# Job details pane not found
# Processed job 54: Data Analyst inom hållbarhet på medarbetarägt konsultbolag | TechSeed | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 55 using JavaScript
# Job details pane not found
# Processed job 55: Data Engineer | Apoteket AB | Solna, Stockholm County, Sweden
# Clicked on job 56 using JavaScript
# Job details pane not found
# Processed job 56: Junior Analytics Engineer | IPercept | Stockholm, Stockholm County, Sweden
# Clicked on job 57 using JavaScript
# Job details pane not found
# Processed job 57: Data Modeller | Capgemini | Stockholm, Stockholm County, Sweden
# Clicked on job 58 using JavaScript
# Job details pane not found
# Processed job 58: Commercial and Business Data Analyst | CSV Rating AB | Stockholm, Stockholm County, Sweden
# Found 58 new jobs
# 'See more jobs' button not found or not visible
# Total jobs collected so far: 58
#
# Iteration 2/5
# Found 118 job listings
# Clicked on job 59 using JavaScript
# Job details pane not found
# Processed job 59: Business Analyst - Data, Analytics & AI Use Cases | inventYOU IT Consulting | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 60 using JavaScript
# Job details pane not found
# Processed job 60: Data Analyst | Signific | Södermalm, Stockholm County, Sweden
# Clicked on job 61 using JavaScript
# Job details pane not found
# Processed job 61: Business Intelligence Analyst | GlobalConnect | Stockholm, Stockholm County, Sweden
# Clicked on job 62 using JavaScript
# Job details pane not found
# Processed job 62: Senior Data Analyst | Trustly | Stockholm, Stockholm County, Sweden
# Clicked on job 63 using JavaScript
# Job details pane not found
# Processed job 63: Data Analyst (0 Experience Required) | Peroptyx | Stockholm County, Sweden
# Clicked on job 64 using JavaScript
# Job details pane not found
# Processed job 64: Reporting & BI - Product & Market, AS Performance | Nissan Motor Corporation | Stockholm, Stockholm County, Sweden
# Clicked on job 65 using JavaScript
# Job details pane not found
# Processed job 65: Senior Data Analyst (m/f/d) | Riverty | Stockholm, Stockholm County, Sweden
# Clicked on job 66 using JavaScript
# Job details pane not found
# Processed job 66: Data Modeller | Whitehall Resources | Stockholm, Stockholm County, Sweden
# Clicked on job 67 using JavaScript
# Job details pane not found
# Processed job 67: Data Analyst | Atea Sverige | Stockholm, Stockholm County, Sweden
# Clicked on job 68 using JavaScript
# Job details pane not found
# Processed job 68: Product Compliance Data Analyst | Polestar | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 69 using JavaScript
# Job details pane not found
# Processed job 69: Samordnare med fokus på datadriven utveckling | Värnamo kommun | Värnamo, Jönköping County, Sweden
# Clicked on job 70 using JavaScript
# Job details pane not found
# Processed job 70: Product Analyst | King | Stockholm, Stockholm County, Sweden
# Clicked on job 71 using JavaScript
# Job details pane not found
# Processed job 71: Quantitative Analyst | Kambi | Stockholm, Stockholm County, Sweden
# Clicked on job 72 using JavaScript
# Job details pane not found
# Processed job 72: Data Engineer | Svenska kraftnät | Stockholm, Stockholm County, Sweden
# Clicked on job 73 using JavaScript
# Job details pane not found
# Processed job 73: Data Engineer | Parallel Consulting | Stockholm, Stockholm County, Sweden
# Clicked on job 74 using JavaScript
# Job details pane not found
# Processed job 74: Data Analyst inom hållbarhet på medarbetarägt konsultbolag | TechSeed | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 75 using JavaScript
# Job details pane not found
# Processed job 75: Data Engineer | Apoteket AB | Solna, Stockholm County, Sweden
# Clicked on job 76 using JavaScript
# Job details pane not found
# Processed job 76: Junior Analytics Engineer | IPercept | Stockholm, Stockholm County, Sweden
# Clicked on job 77 using JavaScript
# Job details pane not found
# Processed job 77: Data Modeller | Capgemini | Stockholm, Stockholm County, Sweden
# Clicked on job 78 using JavaScript
# Job details pane not found
# Processed job 78: Commercial and Business Data Analyst | CSV Rating AB | Stockholm, Stockholm County, Sweden
# Clicked on job 79 using JavaScript
# Job details pane not found
# Processed job 79: Junior Data Engineer | Canonical | Stockholm, Stockholm County, Sweden
# Clicked on job 80 using JavaScript
# Job details pane not found
# Processed job 80: Data Engineer | Joint Academy | Malmo, Skåne County, Sweden
# Clicked on job 81 using JavaScript
# Job details pane not found
# Processed job 81: Analytiker | Kronofogden | Kristinehamns kommun, Värmland County, Sweden
# Clicked on job 82 using JavaScript
# Job details pane not found
# Processed job 82: Senior Consultant - Data & Process Analytics | Celonis | Stockholm, Stockholm County, Sweden
# Clicked on job 83 using JavaScript
# Job details pane not found
# Processed job 83: Internship in Malmö - Analytics / Data Quality | Curamando | Malmo, Skåne County, Sweden
# Clicked on job 84 using JavaScript
# Job details pane not found
# Processed job 84: Data & Market Intelligence Analyst till konsultuppdrag | The Studio Group Sweden AB | Stockholm, Stockholm County, Sweden
# Clicked on job 85 using JavaScript
# Job details pane not found
# Processed job 85: Data Engineer | ComeOn Group | Stockholm, Stockholm County, Sweden
# Clicked on job 86 using JavaScript
# Job details pane not found
# Processed job 86: Data Engineer at The Nutriment Company | The Nutriment Company | Stockholm, Stockholm County, Sweden
# Clicked on job 87 using JavaScript
# Job details pane not found
# Processed job 87: Product Analyst | King | Malmo, Skåne County, Sweden
# Clicked on job 88 using JavaScript
# Job details pane not found
# Processed job 88: Data Engineer | Deploja | Solna, Stockholm County, Sweden
# Clicked on job 89 using JavaScript
# Job details pane not found
# Processed job 89: Software Engineer - Data Analyst | Qlik | Lund, Skåne County, Sweden
# Clicked on job 90 using JavaScript
# Job details pane not found
# Processed job 90: Data Engineer | Coody | Växjö, Kronoberg County, Sweden
# Clicked on job 91 using JavaScript
# Job details pane not found
# Processed job 91: Data Engineer/Data Analyst – Forma framtidens datalösningar med oss! | CGI | Greater Malmö Metropolitan Area
# Clicked on job 92 using JavaScript
# Job details pane not found
# Processed job 92: Juniora Analysts till Operations, Engineering, AI & Data (Stockholm) - Aug 2025 | Deloitte | Stockholm, Stockholm County, Sweden
# Clicked on job 93 using JavaScript
# Job details pane not found
# Processed job 93: Senior Risk Data Analyst to SEB Kort I Stockholm | SEB | Solna, Stockholm County, Sweden
# Clicked on job 94 using JavaScript
# Job details pane not found
# Processed job 94: Power BI Expert | Nikita AB | Stockholm, Stockholm County, Sweden
# Clicked on job 95 using JavaScript
# Job details pane not found
# Processed job 95: Data Engineer | Bookboost | Malmo, Skåne County, Sweden
# Clicked on job 96 using JavaScript
# Job details pane not found
# Processed job 96: Data Engineer | Celsus Engineering AB | Stockholm, Stockholm County, Sweden
# Clicked on job 97 using JavaScript
# Job details pane not found
# Processed job 97: Data Engineer | Flower | Stockholm, Stockholm County, Sweden
# Clicked on job 98 using JavaScript
# Job details pane not found
# Processed job 98: Senior analytiker | Statisticon | Greater Uppsala Metropolitan Area
# Clicked on job 99 using JavaScript
# Job details pane not found
# Processed job 99: Junior Data Scientist | Rasulson Consulting AB | Jönköping, Jönköping County, Sweden
# Clicked on job 100 using JavaScript
# Job details pane not found
# Processed job 100: Data Engineers x2 | emagine | Greater Stockholm Metropolitan Area
# Clicked on job 101 using JavaScript
# Job details pane not found
# Processed job 101: Driven konsult inom BI, Data Analytics och AI | XLENT | Linköping, Östergötland County, Sweden
# Clicked on job 102 using JavaScript
# Job details pane not found
# Processed job 102: Data Engineer | Techster Solutions AB | Stockholm, Stockholm County, Sweden
# Clicked on job 103 using JavaScript
# Job details pane not found
# Processed job 103: Data Engineer | Ving Sverige | Stockholm, Stockholm County, Sweden
# Clicked on job 104 using JavaScript
# Job details pane not found
# Processed job 104: Business Intelligence Konsult | Nexer Group | Gothenburg, Västra Götaland County, Sweden
# Clicked on job 105 using JavaScript
# Job details pane not found
# Processed job 105: Data Engineer | SSC - Swedish Space Corporation | Solna, Stockholm County, Sweden
# Clicked on job 106 using JavaScript
# Job details pane not found
# Processed job 106: Application Specialist | Arctic Business | Luleå, Norrbotten County, Sweden
# Clicked on job 107 using JavaScript
# Job details pane not found
# Processed job 107: Data Engineer | CGI | Karlstad, Värmland County, Sweden
# Clicked on job 108 using JavaScript
# Job details pane not found
# Processed job 108: Senior Data Engineer/Analyst | Xenit AB | Malmo, Skåne County, Sweden
# Clicked on job 109 using JavaScript
# Job details pane not found
# Processed job 109: Data Engineer | B3 Indes | Stockholm, Stockholm County, Sweden
# Clicked on job 110 using JavaScript
# Job details pane not found
# Processed job 110: Research & Insight Consultant - Nordics (m/f/d) | Netigate | Greater Stockholm Metropolitan Area
# Clicked on job 111 using JavaScript
# Job details pane not found
# Processed job 111: Data Engineer | Forefront | Jönköping, Jönköping County, Sweden
# Clicked on job 112 using JavaScript
# Job details pane not found
# Processed job 112: Data Engineer | Luxevision Consulting LLC | Sweden
# Clicked on job 113 using JavaScript
# Job details pane not found
# Processed job 113: Analytics Engineer | NORTH SOUTH AND ASIA PROPERTY INVESTMENT SL | Stockholm, Stockholm County, Sweden
# Clicked on job 114 using JavaScript
# Job details pane not found
# Processed job 114: Data Engineer | CGI | Stockholm, Stockholm County, Sweden
# Clicked on job 115 using JavaScript
# Job details pane not found
# Processed job 115: Vi söker Data Scientists till vår växande analysavdelning | Brixo AB | Stockholm, Stockholm County, Sweden
# Clicked on job 116 using JavaScript
# Job details pane not found
# Processed job 116: Data Engineer Career Program, Sommar 2025, Stockholm | SALT - School of Applied Technology | Stockholm, Stockholm County, Sweden
# Clicked on job 117 using JavaScript
# Job details pane not found
# Processed job 117: Application Specialist | Sirocco Group | Stockholm, Stockholm County, Sweden
# Clicked on job 118 using JavaScript
# Job details pane not found
# Processed job 118: Lead Quant Analyst | Flower | Stockholm, Stockholm County, Sweden
# Found 60 new jobs
# 'See more jobs' button not found or not visible
# Total jobs collected so far: 118
#
# Iteration 3/5
# Found 118 job listings
# No new jobs found in this iteration. Count: 1/2
# 'See more jobs' button not found or not visible
# No more jobs to load, ending scraping
#
# Creating DataFrame with 118 jobs
# Data saved to linkedin_data_analyst_jobs_scraped.csv
#
# Preview of collected data:
#                      Title          Company  \
# 0             Data Analyst      LTIMindtree
# 1  Business & Data Analyst  Karo Healthcare
# 2             Data Analyst              Avy
# 3             Data Analyst       RED Global
# 4             Data Analyst        Capgemini
#
#                                   City Posted Date Applicant Count  \
# 0             Stockholm County, Sweden         N/A             N/A
# 1  Stockholm, Stockholm County, Sweden         N/A             N/A
# 2  Stockholm, Stockholm County, Sweden         N/A             N/A
# 3  Stockholm, Stockholm County, Sweden         N/A             N/A
# 4  Stockholm, Stockholm County, Sweden         N/A             N/A
#
#   Seniority Level Employment Type Job Function Industries
# 0             N/A             N/A          N/A        N/A
# 1             N/A             N/A          N/A        N/A
# 2             N/A             N/A          N/A        N/A
# 3             N/A             N/A          N/A        N/A
# 4             N/A             N/A          N/A        N/A
#
# Total jobs collected: 118
# Unique companies: 83
# Unique cities: 20
# Unique seniority levels: 1
# Unique employment types: 1

# %%
# Close the browser
driver.quit()

# %%
data = pd.read_csv("linkedin_data.csv")
data.head(10)
# Out:
#                                                Title             Company  \
# 0                                       Data Analyst         LTIMindtree
# 1                            Business & Data Analyst     Karo Healthcare
# 2                                       Data Analyst                 Avy
# 3                                       Data Analyst          RED Global
# 4                                       Data Analyst           Capgemini
# 5                                       Data Analyst             Deploja
# 6                                       Data Analyst             Deploja
# 7  Stanowisko ds. zarzƒÖdzania obszarem BI i HD-s...                 ZUS
# 8                                       Data Analyst              Stegra
# 9                                Senior Data Analyst  CloudArt Solutions
#
#                                            City  Posted Date  \
# 0                      Stockholm County, Sweden  2 weeks ago
# 1           Stockholm, Stockholm County, Sweden   1 week ago
# 2           Stockholm, Stockholm County, Sweden  1 month ago
# 3           Stockholm, Stockholm County, Sweden   1 week ago
# 4           Stockholm, Stockholm County, Sweden   6 days ago
# 5               Solna, Stockholm County, Sweden   1 week ago
# 6                  Malmo, Sk√•ne County, Sweden   5 days ago
# 7                                        Sweden   4 days ago
# 8           Stockholm, Stockholm County, Sweden   2 days ago
# 9  Gothenburg, V√§stra G√∂taland County, Sweden   1 week ago
#
#                     Applicant Count   Seniority Level Employment Type  \
# 0                     98 applicants         Executive       Full-time
# 1               Over 200 applicants  Mid-Senior level       Full-time
# 2               Over 200 applicants       Entry level       Full-time
# 3                     99 applicants    Not Applicable        Contract
# 4               Over 200 applicants       Entry level       Full-time
# 5                     57 applicants       Entry level       Full-time
# 6                     68 applicants       Entry level       Full-time
# 7  Be among the first 25 applicants    Not Applicable       Full-time
# 8                    141 applicants       Entry level       Full-time
# 9                     51 applicants  Mid-Senior level       Full-time
#
#                                        Job Function  \
# 0     Consulting, Information Technology, and Other
# 1                                           Analyst
# 2                            Information Technology
# 3                            Information Technology
# 4                            Information Technology
# 5                            Information Technology
# 6                            Information Technology
# 7                                             Other
# 8                            Information Technology
# 9  Engineering, Information Technology, and Analyst
#
#                                           Industries
# 0  IT Services and IT Consulting, Information Ser...
# 1  Non-profit Organizations and Primary and Secon...
# 2                                        Real Estate
# 3                            Staffing and Recruiting
# 4                      IT Services and IT Consulting
# 5                      IT Services and IT Consulting
# 6                      IT Services and IT Consulting
# 7                                          Insurance
# 8                        Primary Metal Manufacturing
# 9                      IT Services and IT Consulting
